# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\mikee\Desktop\Projects\F1-ergast-data-SQL-project\F1-Ergast-data-files\lap_times.csv")
for col in df.columns:
    print(col)
df[:2]
# Out:
# raceId
# driverId
# lap
# position
# time
# milliseconds
#    raceId  driverId  lap  position      time  milliseconds
# 0     841        20    1         1  1:38.109         98109
# 1     841        20    2         1  1:33.006         93006
